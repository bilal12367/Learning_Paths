# %%
import pandas as pd
import numpy as np
data = pd.read_csv('salary_data.csv')

# %%
data.head()

data['Salary'] = np.where(data['Years of Experience'] >= 15, 320000, data['Salary'])
# data['Salary'] = np.where(data['Years of Experience'] > 25, 400000, data['Salary'])

# %%
data.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  320000.0
# 3   60000.0
# 4  320000.0

# %%
data2 = pd.read_csv('salaries.csv')

data2.head()
data2[(data2['Salary'] > 20000) & (data2['Age'] < 60) & (data2['Job'] != 'Dentist')]
# Out:
#               Name  Age                Job  Salary
# 828  Vanessa Burns   59  Software Engineer   20300

# %%
data2.head()
# Out:
#               Name  Age                  Job  Salary
# 0    Kevin Sanders   24    Software Engineer    7300
# 1       Lisa Mills   26  High School Teacher    6100
# 2    Donna Allison   27              Dentist   12700
# 3  Michael Schmitt   43              Dentist   17500
# 4     Lisa Shaffer   31           Accountant    7400

# %%
data2['Experience'] = np.random.randint(1, 23, data2.shape[0])
# Out:
# (1000, 5)

# %%
data2.head()
# Out:
#               Name  Age                  Job  Salary  Experience
# 0    Kevin Sanders   24    Software Engineer    7300           4
# 1       Lisa Mills   26  High School Teacher    6100           6
# 2    Donna Allison   27              Dentist   12700          15
# 3  Michael Schmitt   43              Dentist   17500           6
# 4     Lisa Shaffer   31           Accountant    7400          11

# %%
data['New_Salary'] = np.where((data['Age'] <= 30) & (data['Age'] >= 20), (data['Salary'] + (data['Salary'] * 0.1)), data['Salary'])

# %%
data['New_Salary'] = np.where((data['Age'] <= 40) & (data['Age'] > 30), (data['Salary'] * 1.2), data['New_Salary'])

# %%
data['New_Salary'] = np.where((data['Age'] <= 50) & (data['Age'] > 40), (data['Salary'] * 1.3), data['New_Salary'])

# %%
data.drop(columns=['Salary'],inplace=True)

# %%
data.rename(columns={'New_Salary': 'Salary'}, inplace=True)

# %%
data.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0  108000.0
# 1   71500.0
# 2  195000.0
# 3   72000.0
# 4  200000.0

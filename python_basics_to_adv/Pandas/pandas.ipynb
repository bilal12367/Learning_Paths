# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data.csv')
# select few columns
# data = data[['column1', 'column2', 'column3']]
data = data[['Accident Number', 'Number of Motor Vehicles', 'Number of Injuries' ,'Number of Fatalities', 'Hit and Run', 'City', 'State']]
data.head()
# Out:
#    Accident Number  Number of Motor Vehicles  Number of Injuries  \
# 0       2008473471                       2.0                 2.0
# 1       2008787228                       1.0                 1.0
# 2       2009131786                       1.0                 1.0
# 3       2009418107                       2.0                 0.0
# 4      20120135824                       2.0                 1.0
#
#    Number of Fatalities Hit and Run       City State
# 0                   0.0           N  NASHVILLE    TN
# 1                   0.0           N  NASHVILLE    TN
# 2                   0.0           N  NASHVILLE    TN
# 3                   0.0           Y        NaN    TN
# 4                   0.0           N  NASHVILLE    TN

# %%
a = np.arange(1,10).reshape(3,3)
a = pd.DataFrame(a,columns=['A','B','C'], index=[1,2,3])
a.head(),
a.tail(),
a.info(),
a.describe(),
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 1 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0 bytes
# (         A    B    C
#  count  3.0  3.0  3.0
#  mean   4.0  5.0  6.0
#  std    3.0  3.0  3.0
#  min    1.0  2.0  3.0
#  25%    2.5  3.5  4.5
#  50%    4.0  5.0  6.0
#  75%    5.5  6.5  7.5
#  max    7.0  8.0  9.0,)

# %%
b = pd.read_csv('data.csv')

b['Property Damage'].fillna('None', inplace=True)
b['Illumination Description'].fillna('None', inplace=True)
b['HarmfulDescriptions'].fillna('None', inplace=True)
b.head()
c = b.copy()
# Out:
# /tmp/ipykernel_1625/1911127842.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   b['Property Damage'].fillna('None', inplace=True)
# /tmp/ipykernel_1625/1911127842.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
# Filtering
b.loc[(b['Collision Type Description'] == 'HEAD-ON') & (b['Hit and Run'] == 'Y') & (b['Number of Fatalities'] >= 1.0)]
# Out:
#         Accident Number          Date and Time  Number of Motor Vehicles  \
# 34455       20181007333   12/4/2018 9:25:00 AM                       2.0
# 127506      20210610551  11/30/2021 7:13:00 AM                       0.0
#
#         Number of Injuries  Number of Fatalities Property Damage Hit and Run  \
# 34455                  0.0                   1.0            None           Y
# 127506                 2.0                   1.0            None           Y
#
#        Collision Type Description Weather Description  \
# 34455                     HEAD-ON               CLEAR
# 127506                    HEAD-ON               CLEAR
#
#        Illumination Description  ...  \
# 34455        DARK - NOT LIGHTED  ...
# 127506           DARK - LIGHTED  ...
#
#                                   HarmfulDescriptions ObjectId Zip Code  \
# 34455                MOTOR VEHICLE IN TRANSPORT;DITCH    34456  37135.0
# 127506  MOTOR VEHICLE IN TRANSPORT;Ran Off Road-Right   127507  37013.0
#
# ...

# %%
c['Number of Fatalities'] = c['Number of Fatalities'] * 10

# %%
c.loc[c['Number of Fatalities'] > 0]
# Out:
#         Accident Number          Date and Time  Number of Motor Vehicles  \
# 19          20170728702  8/25/2018 10:12:00 AM                       2.0
# 283         20180009171    1/4/2018 1:18:00 AM                       1.0
# 1031        20180058575  1/19/2018 12:12:00 AM                       1.0
# 1706        20180041747  1/14/2018 12:42:00 AM                       1.0
# 2488        20180066566  1/21/2018 10:12:00 AM                       1.0
# ...                 ...                    ...                       ...
# 214595      20250192635   3/27/2025 6:13:00 AM                       5.0
# 214605      20250193052  3/27/2025 12:53:00 PM                       3.0
# 214700      20250195399   3/28/2025 8:37:00 AM                       1.0
# 214764      20250196835  3/28/2025 11:35:00 PM                       1.0
# 215245      20250203151    4/1/2025 1:34:00 AM                       1.0
#
#         Number of Injuries  Number of Fatalities Property Damage Hit and Run  \
# ...

# %%
c['Hit and Run'] = c['Hit and Run'].replace(to_replace='N', value='No')
c['Hit and Run'] = c['Hit and Run'].replace(to_replace='Y', value='Yes')
c.head()
# Out:
#    Accident Number          Date and Time  Number of Motor Vehicles  \
# 0       2008473471  7/14/2018 11:00:00 PM                       2.0
# 1       2008787228  11/16/2018 9:33:00 AM                       1.0
# 2       2009131786  2/19/2019 10:42:00 PM                       1.0
# 3       2009418107   5/27/2019 9:00:00 PM                       2.0
# 4      20120135824    3/8/2021 6:05:00 PM                       2.0
#
#    Number of Injuries  Number of Fatalities Property Damage Hit and Run  \
# 0                 2.0                   0.0            None          No
# 1                 1.0                   0.0            None          No
# 2                 1.0                   0.0            None          No
# 3                 0.0                   0.0            None         Yes
# 4                 1.0                   0.0            None          No
#
#                 Collision Type Description    Weather Description  \
# ...

# %%
c = c.iloc[:, [1, 2, 3, 4, 5, 6, 7, 10, 11]]
c.head()
# Out:
#            Date and Time  Number of Motor Vehicles  Number of Injuries  \
# 0  7/14/2018 11:00:00 PM                       2.0                 2.0
# 1  11/16/2018 9:33:00 AM                       1.0                 1.0
# 2  2/19/2019 10:42:00 PM                       1.0                 1.0
# 3   5/27/2019 9:00:00 PM                       2.0                 0.0
# 4    3/8/2021 6:05:00 PM                       2.0                 1.0
#
#    Number of Fatalities Property Damage Hit and Run  \
# 0                   0.0            None           N
# 1                   0.0            None           N
# 2                   0.0            None           N
# 3                   0.0            None           Y
# 4                   0.0            None           N
#
#                 Collision Type Description                  Street Address  \
# 0                                    ANGLE       28TH AVE N & JEFFERSON ST
# ...

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216117 entries, 0 to 216116
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Date and Time               216117 non-null  object
#  1   Number of Motor Vehicles    216113 non-null  float64
#  2   Number of Injuries          216114 non-null  float64
#  3   Number of Fatalities        216114 non-null  float64
#  4   Property Damage             216117 non-null  object
#  5   Hit and Run                 216103 non-null  object
#  6   Collision Type Description  203143 non-null  object
#  7   Street Address              215881 non-null  object
#  8   City                        216113 non-null  object
# dtypes: float64(3), object(6)
# memory usage: 14.8+ MB

# %%
c.head()
# Out:
#            Date and Time  Number of Motor Vehicles  Number of Injuries  \
# 0  7/14/2018 11:00:00 PM                       2.0                 2.0
# 1  11/16/2018 9:33:00 AM                       1.0                 1.0
# 2  2/19/2019 10:42:00 PM                       1.0                 1.0
# 3   5/27/2019 9:00:00 PM                       2.0                 0.0
# 4    3/8/2021 6:05:00 PM                       2.0                 1.0
#
#    Number of Fatalities Property Damage Hit and Run  \
# 0                   0.0            None           N
# 1                   0.0            None           N
# 2                   0.0            None           N
# 3                   0.0            None           Y
# 4                   0.0            None           N
#
#                 Collision Type Description                  Street Address  \
# 0                                    ANGLE       28TH AVE N & JEFFERSON ST
# ...

# %%
c.loc[2,'Collision Type Description'] = 'ANGLE'
c.head()
# Out:
#            Date and Time  Number of Motor Vehicles  Number of Injuries  \
# 0  7/14/2018 11:00:00 PM                       2.0                 2.0
# 1  11/16/2018 9:33:00 AM                       1.0                 1.0
# 2  2/19/2019 10:42:00 PM                       1.0                 1.0
# 3   5/27/2019 9:00:00 PM                       2.0                 0.0
# 4    3/8/2021 6:05:00 PM                       2.0                 1.0
#
#    Number of Fatalities Property Damage Hit and Run  \
# 0                   0.0            None           N
# 1                   0.0            None           N
# 2                   0.0            None           N
# 3                   0.0            None           Y
# 4                   0.0            None           N
#
#                 Collision Type Description                  Street Address  \
# 0                                    ANGLE       28TH AVE N & JEFFERSON ST
# ...

# %%
c.sort_values(['Number of Fatalities', 'Number of Injuries'], ascending=[0,1])
# Out:
#                 Date and Time  Number of Motor Vehicles  Number of Injuries  \
# 187319  2/11/2024 12:45:00 PM                       2.0                 1.0
# 168739   6/18/2023 5:07:00 AM                       1.0                 0.0
# 177786   10/8/2023 8:04:00 AM                       1.0                 0.0
# 107551  3/11/2021 10:11:00 PM                       2.0                 1.0
# 186545   2/18/2024 2:39:00 AM                       2.0                 5.0
# ...                       ...                       ...                 ...
# 157910  12/31/2022 1:45:00 PM                       3.0                12.0
# 210371   1/24/2025 6:00:00 AM                       9.0                12.0
# 7       12/22/2020 6:00:00 AM                       NaN                 NaN
# 16133    6/19/2018 4:00:00 PM                       NaN                 NaN
# 22700    8/30/2018 5:58:00 PM                       NaN                 NaN
#
# ...

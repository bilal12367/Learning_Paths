# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import  OneHotEncoder, LabelEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split

data = pd.read_csv('Churn_Modelling.csv')
custom_data = np.array([[600, 'France', 'Male', 40, 3, 60000, 2, 1, 1, 5000]],dtype=object)

X = data.iloc[:,3:-1].values
Y = data.iloc[:,-1].values

sc = StandardScaler()
lblEncoder = LabelEncoder()
hotEncoder = ColumnTransformer(transformers=[('encoder',OneHotEncoder(), [1])],remainder='passthrough')
def encoder(X, hotEncoder,lblEncoder, sc, fit):
    if fit == True:
        X[:, 2] = lblEncoder.fit_transform(X[:, 2])
        X = np.array(hotEncoder.fit_transform(X))
        X = sc.fit_transform(X)
    else: 
        X[:, 2] = lblEncoder.transform(X[:, 2])
        X = np.array(hotEncoder.transform(X))
        X = sc.transform(X)
    return X
X = encoder(X,hotEncoder,lblEncoder,sc, True)

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.4, random_state=1)


print(x_train, x_test, y_train, y_test)
# Out:
# [[ 0.99720391 -0.57873591 -0.57380915 ...  0.64609167 -1.03067011
#    1.62982566]
#  [ 0.99720391 -0.57873591 -0.57380915 ...  0.64609167 -1.03067011
#   -0.62532951]
#  [ 0.99720391 -0.57873591 -0.57380915 ...  0.64609167 -1.03067011
#    0.65011336]
#  ...
#  [ 0.99720391 -0.57873591 -0.57380915 ...  0.64609167  0.97024255
#   -0.14019969]
#  [ 0.99720391 -0.57873591 -0.57380915 ...  0.64609167  0.97024255
#    0.01875682]
#  [-1.00280393  1.72790383 -0.57380915 ...  0.64609167 -1.03067011
#   -1.15858217]] [[ 0.99720391 -0.57873591 -0.57380915 ...  0.64609167  0.97024255
#   -0.05274014]
#  [ 0.99720391 -0.57873591 -0.57380915 ...  0.64609167 -1.03067011
#   -0.58364842]
#  [ 0.99720391 -0.57873591 -0.57380915 ... -1.54776799  0.97024255
#   -0.16611312]
#  ...
#  [ 0.99720391 -0.57873591 -0.57380915 ...  0.64609167  0.97024255
#    0.04194679]
#  [ 0.99720391 -0.57873591 -0.57380915 ...  0.64609167 -1.03067011
#    0.23328545]
# ...

# %%
ann = tf.keras.models.Sequential([
    tf.keras.layers.Dense(units=6, activation='relu'),
    tf.keras.layers.Dense(units=6, activation='relu'),
    tf.keras.layers.Dropout(rate=0.2),
    tf.keras.layers.Dense(units=1, activation='sigmoid')
])

ann.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
ann.fit(x_train, y_train, batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6652 - loss: 0.6659
# Epoch 2/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8005 - loss: 0.5211
# Epoch 3/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8046 - loss: 0.4674
# Epoch 4/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8042 - loss: 0.4651
# Epoch 5/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8016 - loss: 0.4506
# Epoch 6/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7991 - loss: 0.4423
# Epoch 7/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7993 - loss: 0.4360
# Epoch 8/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7924 - loss: 0.4527
# Epoch 9/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8019 - loss: 0.4369
# Epoch 10/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7978 - loss: 0.4362
# Epoch 11/100
# ...

# %%
custom_data1 = encoder(custom_data, hotEncoder, lblEncoder, sc, False)

print(ann.predict(custom_data1) > 0.5)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# [[False]]

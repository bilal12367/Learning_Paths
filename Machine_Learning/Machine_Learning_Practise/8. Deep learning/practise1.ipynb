# %%
import numpy as np
import pandas as pd
import tensorflow as tf

from sklearn.preprocessing import OneHotEncoder,LabelEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split


data = pd.read_csv('Churn_Modelling.csv')

X = data.iloc[:,3:-1].values
Y = data.iloc[:,-1].values

colTransformer = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [1])], remainder='passthrough')
lblEncoder = LabelEncoder()
X[:,2] = lblEncoder.fit_transform(X[:,2])
X = colTransformer.fit_transform(X)
sc = StandardScaler()
X = sc.fit_transform(X)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.4, random_state=1)
print(X_train, X_test, Y_train, Y_test)
# Out:
# [[ 0.99720391 -0.57873591 -0.57380915 ...  0.64609167 -1.03067011
#    1.62982566]
#  [ 0.99720391 -0.57873591 -0.57380915 ...  0.64609167 -1.03067011
#   -0.62532951]
#  [ 0.99720391 -0.57873591 -0.57380915 ...  0.64609167 -1.03067011
#    0.65011336]
#  ...
#  [ 0.99720391 -0.57873591 -0.57380915 ...  0.64609167  0.97024255
#   -0.14019969]
#  [ 0.99720391 -0.57873591 -0.57380915 ...  0.64609167  0.97024255
#    0.01875682]
#  [-1.00280393  1.72790383 -0.57380915 ...  0.64609167 -1.03067011
#   -1.15858217]] [[ 0.99720391 -0.57873591 -0.57380915 ...  0.64609167  0.97024255
#   -0.05274014]
#  [ 0.99720391 -0.57873591 -0.57380915 ...  0.64609167 -1.03067011
#   -0.58364842]
#  [ 0.99720391 -0.57873591 -0.57380915 ... -1.54776799  0.97024255
#   -0.16611312]
#  ...
#  [ 0.99720391 -0.57873591 -0.57380915 ...  0.64609167  0.97024255
#    0.04194679]
#  [ 0.99720391 -0.57873591 -0.57380915 ...  0.64609167 -1.03067011
#    0.23328545]
# ...

# %%
ann = tf.keras.models.Sequential([
    tf.keras.layers.Dense(units=6, activation='relu'),
    tf.keras.layers.Dense(units=6, activation='relu'),
    tf.keras.layers.Dropout(rate=0.2),
    tf.keras.layers.Dense(units=1, activation='sigmoid')
])

ann.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
ann.fit(X_train, Y_train, batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7247 - loss: 0.6028
# Epoch 2/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7908 - loss: 0.5151
# Epoch 3/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8005 - loss: 0.4777
# Epoch 4/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7975 - loss: 0.4645
# Epoch 5/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8090 - loss: 0.4407
# Epoch 6/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8040 - loss: 0.4338
# Epoch 7/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8020 - loss: 0.4306
# Epoch 8/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8151 - loss: 0.4041
# Epoch 9/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8148 - loss: 0.4113
# Epoch 10/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8169 - loss: 0.4120
# Epoch 11/100
# ...

# %%
# customData = np.array([[619, 'Spain', 'Female', 41,2,1000,0,0,0, 900]])
customData = np.array([[700,'France','Female',31,7,1000,0,0,0,900]])
# customData = pd.read_csv('Churn_Modelling.csv').iloc[:,3:-1].values

customData[:,2] = lblEncoder.transform(customData[:,2])
customData = colTransformer.transform(customData)
customData = sc.transform(customData)
res = ann.predict(customData)
test = np.round(sc.inverse_transform(customData), 2).tolist()
inverse_transformed_data = customData.copy()
inverse_transformed_data = colTransformer.named_transformers_['encoder'].inverse_transform(customData[:, 0:3]).reshape(1, len(customData))[0]
for i in range(len(customData)):
    if(res[i] > 0.5):
        print(True)
        print(res[i])
    else:
        print(False)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# True
# [0.5590903]

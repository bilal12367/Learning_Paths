# %%
# %pip install xhtml2pdf
# Out:
# ...
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    ----------------- ---------------------- 1.6/3.5 MB 7.1 MB/s eta 0:00:01
#    -------------------------------- ------- 2.9/3.5 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------- 3.5/3.5 MB 6.9 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    -------------------- ------------------- 2.1/4.1 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------- 4.1/4.1 MB 10.4 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/814.6 kB ? eta -:--:--
#    ---------------------------------------- 814.6/814.6 kB 8.9 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/871.6 kB ? eta -:--:--
#    ---------------------------------------- 871.6/871.6 kB 9.1 MB/s  0:00:00
# ...
#
#    -- -------------------------------------  1/20 [asn1crypto]
#    -- -------------------------------------  1/20 [asn1crypto]
# ...

# %%
from xhtml2pdf import pisa

# enable logging
pisa.showLogging()

html_source = '''<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Resume - Alex Rivera</title>
    <link href="https://fonts.googleapis.com/css2?family=Inter:wght@300;400;600;700&display=swap" rel="stylesheet">
    <style>
        :root {
            --primary-color: #2d3436;
            --accent-color: #0984e3;
            --text-light: #636e72;
            --bg-gray: #f5f6fa;
            --white: #ffffff;
        }

        * {
            margin: 0;
            padding: 0;
            box-sizing: border-box;
        }

        body {
            font-family: 'Inter', sans-serif;
            background-color: var(--bg-gray);
            color: var(--primary-color);
            line-height: 1.6;
            padding: 40px 20px;
        }

        .resume-container {
            max-width: 900px;
            margin: 0 auto;
            background: var(--white);
            display: grid;
            grid-template-columns: 300px 1fr;
            box-shadow: 0 10px 30px rgba(0,0,0,0.1);
        }

        /* Sidebar Styling */
        .sidebar {
            background-color: var(--primary-color);
            color: var(--white);
            padding: 40px 30px;
        }

        .profile-img {
            width: 120px;
            height: 120px;
            background: var(--accent-color);
            border-radius: 50%;
            margin-bottom: 20px;
            display: flex;
            align-items: center;
            justify-content: center;
            font-size: 40px;
            font-weight: bold;
        }

        .sidebar h2 {
            font-size: 1.2rem;
            text-transform: uppercase;
            letter-spacing: 1.5px;
            margin-bottom: 15px;
            border-bottom: 2px solid var(--accent-color);
            display: inline-block;
            padding-bottom: 5px;
        }

        .contact-info, .skills, .education {
            margin-bottom: 40px;
        }

        .info-item {
            margin-bottom: 15px;
            font-size: 0.9rem;
        }

        .info-item span {
            display: block;
            color: #b2bec3;
            font-weight: 600;
            font-size: 0.75rem;
            text-transform: uppercase;
        }

        .skill-tag {
            display: inline-block;
            background: rgba(255,255,255,0.1);
            padding: 5px 12px;
            border-radius: 4px;
            margin: 0 5px 10px 0;
            font-size: 0.85rem;
        }

        /* Main Content Styling */
        .main-content {
            padding: 50px;
        }

        .header {
            margin-bottom: 40px;
        }

        .header h1 {
            font-size: 2.8rem;
            text-transform: uppercase;
            letter-spacing: -1px;
            line-height: 1;
        }

        .header p {
            font-size: 1.1rem;
            color: var(--accent-color);
            font-weight: 600;
            margin-top: 10px;
        }

        .section {
            margin-bottom: 35px;
        }

        .section-title {
            font-size: 1.4rem;
            margin-bottom: 20px;
            color: var(--primary-color);
            position: relative;
        }

        .experience-item {
            margin-bottom: 25px;
        }

        .job-meta {
            display: flex;
            justify-content: space-between;
            align-items: baseline;
        }

        .job-title {
            font-weight: 700;
            font-size: 1.1rem;
        }

        .job-date {
            font-size: 0.85rem;
            color: var(--text-light);
        }

        .company {
            color: var(--accent-color);
            font-weight: 600;
            font-size: 0.95rem;
            margin-bottom: 8px;
        }

        .job-desc {
            font-size: 0.95rem;
            color: var(--text-light);
            list-style-position: inside;
        }

        .job-desc li {
            margin-bottom: 5px;
        }

        /* Responsive */
        @media (max-width: 768px) {
            .resume-container {
                grid-template-columns: 1fr;
            }
            .sidebar {
                padding: 40px;
            }
        }

        /* Print Settings */
        @media print {
            body { background: none; padding: 0; }
            .resume-container { box-shadow: none; width: 100%; }
        }
    </style>
</head>
<body>

    <div class="resume-container">
        <aside class="sidebar">
            <div class="profile-img">AR</div>
            
            <div class="contact-info">
                <h2>Contact</h2>
                <div class="info-item">
                    <span>Phone</span>
                    +1 (555) 012-3456
                </div>
                <div class="info-item">
                    <span>Email</span>
                    alex.rivera@email.com
                </div>
                <div class="info-item">
                    <span>Location</span>
                    San Francisco, CA
                </div>
                <div class="info-item">
                    <span>Website</span>
                    www.arivera.dev
                </div>
            </div>

            <div class="skills">
                <h2>Skills</h2>
                <div class="skill-tag">JavaScript</div>
                <div class="skill-tag">React.js</div>
                <div class="skill-tag">Node.js</div>
                <div class="skill-tag">Python</div>
                <div class="skill-tag">AWS</div>
                <div class="skill-tag">UI/UX Design</div>
                <div class="skill-tag">Git</div>
                <div class="skill-tag">Agile</div>
            </div>

            <div class="education">
                <h2>Education</h2>
                <div class="info-item">
                    <span>2016 - 2020</span>
                    <strong>B.S. Computer Science</strong><br>
                    Stanford University
                </div>
            </div>
        </aside>

        <main class="main-content">
            <header class="header">
                <h1>Alex Rivera</h1>
                <p>Senior Full-Stack Developer</p>
            </header>

            <section class="section">
                <h2 class="section-title">Summary</h2>
                <p class="job-desc">
                    Innovative Full-Stack Developer with 5+ years of experience building scalable web applications. 
                    Proven track record in improving system performance and leading cross-functional teams to 
                    deliver high-quality software solutions.
                </p>
            </section>

            <section class="section">
                <h2 class="section-title">Experience</h2>

                <div class="experience-item">
                    <div class="job-meta">
                        <span class="job-title">Senior Software Engineer</span>
                        <span class="job-date">2022 - Present</span>
                    </div>
                    <div class="company">TechFlow Solutions</div>
                    <ul class="job-desc">
                        <li>Architected a microservices-based dashboard that reduced loading times by 40%.</li>
                        <li>Mentored a team of 5 junior developers, improving sprint velocity by 20%.</li>
                        <li>Implemented CI/CD pipelines using GitHub Actions, reducing deployment errors.</li>
                    </ul>
                </div>

                <div class="experience-item">
                    <div class="job-meta">
                        <span class="job-title">Full Stack Developer</span>
                        <span class="job-date">2020 - 2022</span>
                    </div>
                    <div class="company">Innovate Digital</div>
                    <ul class="job-desc">
                        <li>Developed responsive e-commerce platforms using React and Stripe API.</li>
                        <li>Optimized database queries in PostgreSQL, leading to a 30% faster data retrieval rate.</li>
                        <li>Collaborated with design teams to translate Figma wireframes into pixel-perfect code.</li>
                    </ul>
                </div>

                <div class="experience-item">
                    <div class="job-meta">
                        <span class="job-title">Web Development Intern</span>
                        <span class="job-date">2019 - 2020</span>
                    </div>
                    <div class="company">StartUp Hub</div>
                    <ul class="job-desc">
                        <li>Assisted in the maintenance of client-facing websites using HTML, CSS, and jQuery.</li>
                        <li>Fixed critical UI bugs and improved accessibility compliance (WCAG).</li>
                    </ul>
                </div>
            </section>

            <section class="section">
                <h2 class="section-title">Key Projects</h2>
                <div class="experience-item">
                    <div class="job-title">OpenSource Analytics Engine</div>
                    <p class="job-desc">Created a lightweight tracking script that handles 1M+ monthly events with minimal latency.</p>
                </div>
            </section>
        </main>
    </div>

</body>
</html>'''

with open("test.pdf", "w+b") as result_file:
    # convert HTML to PDF
    pisa_status = pisa.CreatePDF(
        html_source,       # page data
        dest=result_file,  # destination file
    )

    # Check for errors
    if pisa_status.err:
        print("An error occurred!")
# Out:
# WARNING [xhtml2pdf.context] c:\Users\Administrator\Documents\Workspace\python\.venv\Lib\site-packages\xhtml2pdf\context.py line 204: @fontface, unknown value font-weight '300'
#
# ERROR [xhtml2pdf.context] c:\Users\Administrator\Documents\Workspace\python\.venv\Lib\site-packages\xhtml2pdf\context.py line 522: Error while parsing CSS file
# Traceback (most recent call last):
#   File "c:\Users\Administrator\Documents\Workspace\python\.venv\Lib\site-packages\reportlab\lib\utils.py", line 523, in open_for_read
#     return open_for_read_by_name(name,mode)
#   File "c:\Users\Administrator\Documents\Workspace\python\.venv\Lib\site-packages\reportlab\lib\utils.py", line 463, in open_for_read_by_name
#     return open(name,mode)
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\ADMINI~1\\AppData\\Local\\Temp\\tmpo4nj90hf'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...

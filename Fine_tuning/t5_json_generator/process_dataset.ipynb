# %%
# %pip install datasets kagglehub
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
pii_dataset = pd.read_csv('pii_dataset.csv')

# %%
pii_dataset.size
# Out:
# 70944

# %%
import numpy, json
pii_columns = pii_dataset.columns[7:15]
pii_dataset['json'] = ''
for ind, row in pii_dataset.iterrows():
    text = row[1]
    json_obj = {}  
    for col in pii_columns:
        json_obj[col] = row[col] if row[col] != numpy.nan else None
    # row['json'] = json.dumps(json_obj)
    pii_dataset.at[ind, 'json'] = json.dumps(json_obj)
    # if ind > 5: 
    #     break
# Out:
# /tmp/ipykernel_10451/3548272308.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   text = row[1]

# %%
pii_dataset.head()
pii_dataset.to_csv('processed_pii_dataset.csv', index=False)

# %%
pii_dataset.size()

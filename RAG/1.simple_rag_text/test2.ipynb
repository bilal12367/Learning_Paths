# %%
# %pip install accelerate
# Out:
# Requirement already satisfied: accelerate in e:\new_workspace\ai\.venv\lib\site-packages (1.6.0)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in e:\new_workspace\ai\.venv\lib\site-packages (from accelerate) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in e:\new_workspace\ai\.venv\lib\site-packages (from accelerate) (24.2)
# Requirement already satisfied: psutil in e:\new_workspace\ai\.venv\lib\site-packages (from accelerate) (7.0.0)
# Requirement already satisfied: pyyaml in e:\new_workspace\ai\.venv\lib\site-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=2.0.0 in e:\new_workspace\ai\.venv\lib\site-packages (from accelerate) (2.7.0)
# Requirement already satisfied: huggingface-hub>=0.21.0 in e:\new_workspace\ai\.venv\lib\site-packages (from accelerate) (0.30.2)
# Requirement already satisfied: safetensors>=0.4.3 in e:\new_workspace\ai\.venv\lib\site-packages (from accelerate) (0.5.3)
# Requirement already satisfied: filelock in e:\new_workspace\ai\.venv\lib\site-packages (from huggingface-hub>=0.21.0->accelerate) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in e:\new_workspace\ai\.venv\lib\site-packages (from huggingface-hub>=0.21.0->accelerate) (2024.12.0)
# Requirement already satisfied: requests in e:\new_workspace\ai\.venv\lib\site-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in e:\new_workspace\ai\.venv\lib\site-packages (from huggingface-hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in e:\new_workspace\ai\.venv\lib\site-packages (from huggingface-hub>=0.21.0->accelerate) (4.13.2)
# Requirement already satisfied: sympy>=1.13.3 in e:\new_workspace\ai\.venv\lib\site-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx in e:\new_workspace\ai\.venv\lib\site-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in e:\new_workspace\ai\.venv\lib\site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in e:\new_workspace\ai\.venv\lib\site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: colorama in e:\new_workspace\ai\.venv\lib\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.21.0->accelerate) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\new_workspace\ai\.venv\lib\site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\new_workspace\ai\.venv\lib\site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in e:\new_workspace\ai\.venv\lib\site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\new_workspace\ai\.venv\lib\site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in e:\new_workspace\ai\.venv\lib\site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from diffusers import DiffusionPipeline
from IPython.display import display

pipe = DiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4")
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
pipe = pipe.to('cuda')
pipe.enable_xformers_memory_efficient_attention()

def generateImage(prompt):
    image = pipe(prompt, num_inference_steps=20).images[0]
    display(image)

# %%
generateImage("Old fort on the huge mountain")
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
generateImage('Cloudy rainy road with trees aside of the road')
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
